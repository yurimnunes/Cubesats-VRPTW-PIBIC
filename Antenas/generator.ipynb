# %%
import json
import random
import uuid
from datetime import datetime, timedelta

# Convert a datetime to minutes since epoch
def datetime_to_minutes(dt):
    return int(dt.timestamp() // 60)

# Generate random minutes within a given range
def generate_random_minutes(start_minutes, end_minutes):
    return int(random.uniform(start_minutes, end_minutes))

# Generate view periods for resources
def generate_view_periods(start_minutes, end_minutes, num_periods=3):
    periods = []
    period_duration = (end_minutes - start_minutes) // num_periods
    for i in range(num_periods):
        rise = start_minutes + period_duration * i
        set_time = rise + int(random.uniform(60, 240))  # Duration between 1 to 4 hours in minutes
        periods.append({
            "RISE": rise,
            "SET": set_time,
            "TRX ON": rise,
            "TRX OFF": set_time
        })
    return periods

# Generate track data for a given week and year
def generate_track_data(week, year, num_tracks):
    start_week = datetime.strptime(f'{year} {week} 1', '%Y %W %w')
    start_week_minutes = 0
    data = []
    for _ in range(num_tracks):
        duration = int(random.uniform(60, 2*60))  # Duration between 1 to 3.5 hours in minutes
        setup_time = 60
        teardown_time = 15
        track_id = str(uuid.uuid4())
        time_window_start = start_week_minutes + generate_random_minutes(0, 6.5 * 24 * 60 * 1)  # Random start within the week
        time_window_end = time_window_start + generate_random_minutes(1 * 60, 1.5 * 60)  # Random end 1 to 2 hours later
        
        if random.random() < 0.9:
            resources = random.sample(["DSS-24", "DSS-26", "DSS-34", "DSS-36", "DSS-54"], k=2)
            # concatenate name with _
            resources = ["_".join(resources)]
        else:
            resources = random.sample(["DSS-24", "DSS-26", "DSS-34", "DSS-36", "DSS-54"], k=random.randint(1, 5))
        resource_vp_dict = {res: generate_view_periods(time_window_start, time_window_end) for res in resources}
        
        track = {
            "subject": 521,
            "user": "521_0",
            "week": week,
            "year": year,
            "duration": duration,
            "duration_min": duration,
            "resources": [[res] for res in resources],
            "track_id": track_id,
            "setup_time": setup_time,
            "teardown_time": teardown_time,
            "time_window_start": time_window_start,
            "time_window_end": time_window_end,
            "resource_vp_dict": resource_vp_dict
        }
        data.append(track)
    return data


# Generate DSN data for a range of weeks and a given year
def generate_dsn_data(weeks, year, num_tracks_per_week):
    dsn_data = {}
    for week in weeks:
        week_key = f"W{week}_{year}"
        dsn_data[week_key] = generate_track_data(week, year, num_tracks_per_week)
    return dsn_data

if __name__ == "__main__":
    weeks = [10]
    year = 2018
    num_tracks_per_week = 50
    dsn_data = generate_dsn_data(weeks, year, num_tracks_per_week)
    
    with open("build/toy_problem.json", "w") as file:
        json.dump(dsn_data, file, indent=2)
    
    print("DSN test data generated successfully.")
# Out:
# DSN test data generated successfully.

# %%
dsn_data
# Out:
# {'W10_2018': [{'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 73,
#    'duration_min': 73,
#    'resources': [['DSS-26'], ['DSS-36'], ['DSS-24'], ['DSS-34']],
#    'track_id': '3a667696-67d9-40b2-8365-f34ce257ca65',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7397,
#    'time_window_end': 7464,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 7397,
#       'SET': 7541,
#       'TRX ON': 7397,
#       'TRX OFF': 7541},
#      {'RISE': 7419, 'SET': 7628, 'TRX ON': 7419, 'TRX OFF': 7628},
#      {'RISE': 7441, 'SET': 7655, 'TRX ON': 7441, 'TRX OFF': 7655}],
#     'DSS-36': [{'RISE': 7397, 'SET': 7583, 'TRX ON': 7397, 'TRX OFF': 7583},
#      {'RISE': 7419, 'SET': 7598, 'TRX ON': 7419, 'TRX OFF': 7598},
#      {'RISE': 7441, 'SET': 7662, 'TRX ON': 7441, 'TRX OFF': 7662}],
#     'DSS-24': [{'RISE': 7397, 'SET': 7509, 'TRX ON': 7397, 'TRX OFF': 7509},
#      {'RISE': 7419, 'SET': 7604, 'TRX ON': 7419, 'TRX OFF': 7604},
#      {'RISE': 7441, 'SET': 7559, 'TRX ON': 7441, 'TRX OFF': 7559}],
#     'DSS-34': [{'RISE': 7397, 'SET': 7537, 'TRX ON': 7397, 'TRX OFF': 7537},
#      {'RISE': 7419, 'SET': 7597, 'TRX ON': 7419, 'TRX OFF': 7597},
#      {'RISE': 7441, 'SET': 7501, 'TRX ON': 7441, 'TRX OFF': 7501}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 62,
#    'duration_min': 62,
#    'resources': [['DSS-24'], ['DSS-26'], ['DSS-54']],
#    'track_id': '68786aea-b4e2-43f8-a42d-9a7589d0f99a',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 6883,
#    'time_window_end': 6950,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 6883,
#       'SET': 7031,
#       'TRX ON': 6883,
#       'TRX OFF': 7031},
#      {'RISE': 6905, 'SET': 6977, 'TRX ON': 6905, 'TRX OFF': 6977},
#      {'RISE': 6927, 'SET': 7074, 'TRX ON': 6927, 'TRX OFF': 7074}],
#     'DSS-26': [{'RISE': 6883, 'SET': 7033, 'TRX ON': 6883, 'TRX OFF': 7033},
#      {'RISE': 6905, 'SET': 7039, 'TRX ON': 6905, 'TRX OFF': 7039},
#      {'RISE': 6927, 'SET': 7014, 'TRX ON': 6927, 'TRX OFF': 7014}],
#     'DSS-54': [{'RISE': 6883, 'SET': 7002, 'TRX ON': 6883, 'TRX OFF': 7002},
#      {'RISE': 6905, 'SET': 7060, 'TRX ON': 6905, 'TRX OFF': 7060},
#      {'RISE': 6927, 'SET': 7129, 'TRX ON': 6927, 'TRX OFF': 7129}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 113,
#    'duration_min': 113,
#    'resources': [['DSS-24'], ['DSS-34']],
#    'track_id': 'd6734bf7-cd5a-4361-98a3-d5d101186348',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4715,
#    'time_window_end': 4796,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 4715,
#       'SET': 4869,
#       'TRX ON': 4715,
#       'TRX OFF': 4869},
#      {'RISE': 4742, 'SET': 4936, 'TRX ON': 4742, 'TRX OFF': 4936},
#      {'RISE': 4769, 'SET': 4857, 'TRX ON': 4769, 'TRX OFF': 4857}],
#     'DSS-34': [{'RISE': 4715, 'SET': 4907, 'TRX ON': 4715, 'TRX OFF': 4907},
#      {'RISE': 4742, 'SET': 4827, 'TRX ON': 4742, 'TRX OFF': 4827},
#      {'RISE': 4769, 'SET': 4995, 'TRX ON': 4769, 'TRX OFF': 4995}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 81,
#    'duration_min': 81,
#    'resources': [['DSS-54'], ['DSS-26'], ['DSS-34'], ['DSS-24']],
#    'track_id': 'a4193047-29d6-4dd6-8597-fe83444988c5',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 158,
#    'time_window_end': 223,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 158,
#       'SET': 332,
#       'TRX ON': 158,
#       'TRX OFF': 332},
#      {'RISE': 179, 'SET': 272, 'TRX ON': 179, 'TRX OFF': 272},
#      {'RISE': 200, 'SET': 285, 'TRX ON': 200, 'TRX OFF': 285}],
#     'DSS-26': [{'RISE': 158, 'SET': 274, 'TRX ON': 158, 'TRX OFF': 274},
#      {'RISE': 179, 'SET': 338, 'TRX ON': 179, 'TRX OFF': 338},
#      {'RISE': 200, 'SET': 261, 'TRX ON': 200, 'TRX OFF': 261}],
#     'DSS-34': [{'RISE': 158, 'SET': 295, 'TRX ON': 158, 'TRX OFF': 295},
#      {'RISE': 179, 'SET': 370, 'TRX ON': 179, 'TRX OFF': 370},
#      {'RISE': 200, 'SET': 358, 'TRX ON': 200, 'TRX OFF': 358}],
#     'DSS-24': [{'RISE': 158, 'SET': 284, 'TRX ON': 158, 'TRX OFF': 284},
#      {'RISE': 179, 'SET': 298, 'TRX ON': 179, 'TRX OFF': 298},
#      {'RISE': 200, 'SET': 362, 'TRX ON': 200, 'TRX OFF': 362}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 104,
#    'duration_min': 104,
#    'resources': [['DSS-24'], ['DSS-26'], ['DSS-36'], ['DSS-34'], ['DSS-54']],
#    'track_id': '29257584-4d39-43c9-b396-cbfddd4c574c',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 1559,
#    'time_window_end': 1638,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 1559,
#       'SET': 1726,
#       'TRX ON': 1559,
#       'TRX OFF': 1726},
#      {'RISE': 1585, 'SET': 1782, 'TRX ON': 1585, 'TRX OFF': 1782},
#      {'RISE': 1611, 'SET': 1751, 'TRX ON': 1611, 'TRX OFF': 1751}],
#     'DSS-26': [{'RISE': 1559, 'SET': 1789, 'TRX ON': 1559, 'TRX OFF': 1789},
#      {'RISE': 1585, 'SET': 1815, 'TRX ON': 1585, 'TRX OFF': 1815},
#      {'RISE': 1611, 'SET': 1804, 'TRX ON': 1611, 'TRX OFF': 1804}],
#     'DSS-36': [{'RISE': 1559, 'SET': 1668, 'TRX ON': 1559, 'TRX OFF': 1668},
#      {'RISE': 1585, 'SET': 1730, 'TRX ON': 1585, 'TRX OFF': 1730},
#      {'RISE': 1611, 'SET': 1674, 'TRX ON': 1611, 'TRX OFF': 1674}],
#     'DSS-34': [{'RISE': 1559, 'SET': 1662, 'TRX ON': 1559, 'TRX OFF': 1662},
#      {'RISE': 1585, 'SET': 1816, 'TRX ON': 1585, 'TRX OFF': 1816},
#      {'RISE': 1611, 'SET': 1749, 'TRX ON': 1611, 'TRX OFF': 1749}],
#     'DSS-54': [{'RISE': 1559, 'SET': 1639, 'TRX ON': 1559, 'TRX OFF': 1639},
#      {'RISE': 1585, 'SET': 1663, 'TRX ON': 1585, 'TRX OFF': 1663},
#      {'RISE': 1611, 'SET': 1830, 'TRX ON': 1611, 'TRX OFF': 1830}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 74,
#    'duration_min': 74,
#    'resources': [['DSS-36'], ['DSS-24'], ['DSS-34'], ['DSS-26']],
#    'track_id': 'c14577c5-6566-41a7-9c49-c20b3296b7e2',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7428,
#    'time_window_end': 7509,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 7428,
#       'SET': 7609,
#       'TRX ON': 7428,
#       'TRX OFF': 7609},
#      {'RISE': 7455, 'SET': 7526, 'TRX ON': 7455, 'TRX OFF': 7526},
#      {'RISE': 7482, 'SET': 7697, 'TRX ON': 7482, 'TRX OFF': 7697}],
#     'DSS-24': [{'RISE': 7428, 'SET': 7563, 'TRX ON': 7428, 'TRX OFF': 7563},
#      {'RISE': 7455, 'SET': 7597, 'TRX ON': 7455, 'TRX OFF': 7597},
#      {'RISE': 7482, 'SET': 7638, 'TRX ON': 7482, 'TRX OFF': 7638}],
#     'DSS-34': [{'RISE': 7428, 'SET': 7568, 'TRX ON': 7428, 'TRX OFF': 7568},
#      {'RISE': 7455, 'SET': 7575, 'TRX ON': 7455, 'TRX OFF': 7575},
#      {'RISE': 7482, 'SET': 7553, 'TRX ON': 7482, 'TRX OFF': 7553}],
#     'DSS-26': [{'RISE': 7428, 'SET': 7664, 'TRX ON': 7428, 'TRX OFF': 7664},
#      {'RISE': 7455, 'SET': 7610, 'TRX ON': 7455, 'TRX OFF': 7610},
#      {'RISE': 7482, 'SET': 7623, 'TRX ON': 7482, 'TRX OFF': 7623}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 102,
#    'duration_min': 102,
#    'resources': [['DSS-36'], ['DSS-54']],
#    'track_id': 'af9d071c-c021-408a-9320-8f0919cdb3dd',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4796,
#    'time_window_end': 4882,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 4796,
#       'SET': 4913,
#       'TRX ON': 4796,
#       'TRX OFF': 4913},
#      {'RISE': 4824, 'SET': 4967, 'TRX ON': 4824, 'TRX OFF': 4967},
#      {'RISE': 4852, 'SET': 5063, 'TRX ON': 4852, 'TRX OFF': 5063}],
#     'DSS-54': [{'RISE': 4796, 'SET': 4864, 'TRX ON': 4796, 'TRX OFF': 4864},
#      {'RISE': 4824, 'SET': 5033, 'TRX ON': 4824, 'TRX OFF': 5033},
#      {'RISE': 4852, 'SET': 5086, 'TRX ON': 4852, 'TRX OFF': 5086}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 86,
#    'duration_min': 86,
#    'resources': [['DSS-26']],
#    'track_id': '86b3be87-36c3-4c15-8b2b-d66a92e59cc4',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 1775,
#    'time_window_end': 1839,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 1775,
#       'SET': 1882,
#       'TRX ON': 1775,
#       'TRX OFF': 1882},
#      {'RISE': 1796, 'SET': 1938, 'TRX ON': 1796, 'TRX OFF': 1938},
#      {'RISE': 1817, 'SET': 1904, 'TRX ON': 1817, 'TRX OFF': 1904}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 115,
#    'duration_min': 115,
#    'resources': [['DSS-24'], ['DSS-54'], ['DSS-36']],
#    'track_id': 'aa2ac82c-8462-43b0-adc8-493c7a0206b2',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4685,
#    'time_window_end': 4761,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 4685,
#       'SET': 4746,
#       'TRX ON': 4685,
#       'TRX OFF': 4746},
#      {'RISE': 4710, 'SET': 4889, 'TRX ON': 4710, 'TRX OFF': 4889},
#      {'RISE': 4735, 'SET': 4930, 'TRX ON': 4735, 'TRX OFF': 4930}],
#     'DSS-54': [{'RISE': 4685, 'SET': 4839, 'TRX ON': 4685, 'TRX OFF': 4839},
#      {'RISE': 4710, 'SET': 4920, 'TRX ON': 4710, 'TRX OFF': 4920},
#      {'RISE': 4735, 'SET': 4965, 'TRX ON': 4735, 'TRX OFF': 4965}],
#     'DSS-36': [{'RISE': 4685, 'SET': 4839, 'TRX ON': 4685, 'TRX OFF': 4839},
#      {'RISE': 4710, 'SET': 4914, 'TRX ON': 4710, 'TRX OFF': 4914},
#      {'RISE': 4735, 'SET': 4913, 'TRX ON': 4735, 'TRX OFF': 4913}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 112,
#    'duration_min': 112,
#    'resources': [['DSS-24'], ['DSS-26'], ['DSS-34'], ['DSS-54']],
#    'track_id': 'e9276a23-d06d-4d72-8ddc-2b9410a81a44',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 3678,
#    'time_window_end': 3742,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 3678,
#       'SET': 3790,
#       'TRX ON': 3678,
#       'TRX OFF': 3790},
#      {'RISE': 3699, 'SET': 3911, 'TRX ON': 3699, 'TRX OFF': 3911},
#      {'RISE': 3720, 'SET': 3869, 'TRX ON': 3720, 'TRX OFF': 3869}],
#     'DSS-26': [{'RISE': 3678, 'SET': 3738, 'TRX ON': 3678, 'TRX OFF': 3738},
#      {'RISE': 3699, 'SET': 3862, 'TRX ON': 3699, 'TRX OFF': 3862},
#      {'RISE': 3720, 'SET': 3956, 'TRX ON': 3720, 'TRX OFF': 3956}],
#     'DSS-34': [{'RISE': 3678, 'SET': 3788, 'TRX ON': 3678, 'TRX OFF': 3788},
#      {'RISE': 3699, 'SET': 3842, 'TRX ON': 3699, 'TRX OFF': 3842},
#      {'RISE': 3720, 'SET': 3848, 'TRX ON': 3720, 'TRX OFF': 3848}],
#     'DSS-54': [{'RISE': 3678, 'SET': 3786, 'TRX ON': 3678, 'TRX OFF': 3786},
#      {'RISE': 3699, 'SET': 3778, 'TRX ON': 3699, 'TRX OFF': 3778},
#      {'RISE': 3720, 'SET': 3836, 'TRX ON': 3720, 'TRX OFF': 3836}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 74,
#    'duration_min': 74,
#    'resources': [['DSS-36'], ['DSS-54']],
#    'track_id': 'e40116d6-1299-4673-bb64-8ee98761634e',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 6211,
#    'time_window_end': 6275,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 6211,
#       'SET': 6437,
#       'TRX ON': 6211,
#       'TRX OFF': 6437},
#      {'RISE': 6232, 'SET': 6418, 'TRX ON': 6232, 'TRX OFF': 6418},
#      {'RISE': 6253, 'SET': 6366, 'TRX ON': 6253, 'TRX OFF': 6366}],
#     'DSS-54': [{'RISE': 6211, 'SET': 6324, 'TRX ON': 6211, 'TRX OFF': 6324},
#      {'RISE': 6232, 'SET': 6354, 'TRX ON': 6232, 'TRX OFF': 6354},
#      {'RISE': 6253, 'SET': 6446, 'TRX ON': 6253, 'TRX OFF': 6446}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 105,
#    'duration_min': 105,
#    'resources': [['DSS-54']],
#    'track_id': 'bbdceedc-46aa-416f-8cb7-c82cd6da2d05',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5310,
#    'time_window_end': 5370,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 5310,
#       'SET': 5423,
#       'TRX ON': 5310,
#       'TRX OFF': 5423},
#      {'RISE': 5330, 'SET': 5516, 'TRX ON': 5330, 'TRX OFF': 5516},
#      {'RISE': 5350, 'SET': 5538, 'TRX ON': 5350, 'TRX OFF': 5538}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 79,
#    'duration_min': 79,
#    'resources': [['DSS-24'], ['DSS-54']],
#    'track_id': 'cded4300-4a76-403e-8479-a4aedf66c85c',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 8570,
#    'time_window_end': 8654,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 8570,
#       'SET': 8691,
#       'TRX ON': 8570,
#       'TRX OFF': 8691},
#      {'RISE': 8598, 'SET': 8731, 'TRX ON': 8598, 'TRX OFF': 8731},
#      {'RISE': 8626, 'SET': 8811, 'TRX ON': 8626, 'TRX OFF': 8811}],
#     'DSS-54': [{'RISE': 8570, 'SET': 8735, 'TRX ON': 8570, 'TRX OFF': 8735},
#      {'RISE': 8598, 'SET': 8731, 'TRX ON': 8598, 'TRX OFF': 8731},
#      {'RISE': 8626, 'SET': 8719, 'TRX ON': 8626, 'TRX OFF': 8719}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 83,
#    'duration_min': 83,
#    'resources': [['DSS-54'], ['DSS-24'], ['DSS-36'], ['DSS-34']],
#    'track_id': 'dc6326f0-52c8-400c-8381-d36534775171',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5813,
#    'time_window_end': 5889,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 5813,
#       'SET': 6013,
#       'TRX ON': 5813,
#       'TRX OFF': 6013},
#      {'RISE': 5838, 'SET': 5926, 'TRX ON': 5838, 'TRX OFF': 5926},
#      {'RISE': 5863, 'SET': 5965, 'TRX ON': 5863, 'TRX OFF': 5965}],
#     'DSS-24': [{'RISE': 5813, 'SET': 5955, 'TRX ON': 5813, 'TRX OFF': 5955},
#      {'RISE': 5838, 'SET': 6011, 'TRX ON': 5838, 'TRX OFF': 6011},
#      {'RISE': 5863, 'SET': 6056, 'TRX ON': 5863, 'TRX OFF': 6056}],
#     'DSS-36': [{'RISE': 5813, 'SET': 5980, 'TRX ON': 5813, 'TRX OFF': 5980},
#      {'RISE': 5838, 'SET': 5950, 'TRX ON': 5838, 'TRX OFF': 5950},
#      {'RISE': 5863, 'SET': 6065, 'TRX ON': 5863, 'TRX OFF': 6065}],
#     'DSS-34': [{'RISE': 5813, 'SET': 5972, 'TRX ON': 5813, 'TRX OFF': 5972},
#      {'RISE': 5838, 'SET': 6026, 'TRX ON': 5838, 'TRX OFF': 6026},
#      {'RISE': 5863, 'SET': 5942, 'TRX ON': 5863, 'TRX OFF': 5942}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 90,
#    'duration_min': 90,
#    'resources': [['DSS-54'], ['DSS-26'], ['DSS-24'], ['DSS-34']],
#    'track_id': 'd6bf3a85-9077-4b05-bcc6-192fc60bf4f0',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 2320,
#    'time_window_end': 2387,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 2320,
#       'SET': 2533,
#       'TRX ON': 2320,
#       'TRX OFF': 2533},
#      {'RISE': 2342, 'SET': 2472, 'TRX ON': 2342, 'TRX OFF': 2472},
#      {'RISE': 2364, 'SET': 2446, 'TRX ON': 2364, 'TRX OFF': 2446}],
#     'DSS-26': [{'RISE': 2320, 'SET': 2519, 'TRX ON': 2320, 'TRX OFF': 2519},
#      {'RISE': 2342, 'SET': 2430, 'TRX ON': 2342, 'TRX OFF': 2430},
#      {'RISE': 2364, 'SET': 2593, 'TRX ON': 2364, 'TRX OFF': 2593}],
#     'DSS-24': [{'RISE': 2320, 'SET': 2398, 'TRX ON': 2320, 'TRX OFF': 2398},
#      {'RISE': 2342, 'SET': 2566, 'TRX ON': 2342, 'TRX OFF': 2566},
#      {'RISE': 2364, 'SET': 2477, 'TRX ON': 2364, 'TRX OFF': 2477}],
#     'DSS-34': [{'RISE': 2320, 'SET': 2453, 'TRX ON': 2320, 'TRX OFF': 2453},
#      {'RISE': 2342, 'SET': 2575, 'TRX ON': 2342, 'TRX OFF': 2575},
#      {'RISE': 2364, 'SET': 2537, 'TRX ON': 2364, 'TRX OFF': 2537}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 69,
#    'duration_min': 69,
#    'resources': [['DSS-54'], ['DSS-24'], ['DSS-26']],
#    'track_id': '5cb9e877-124f-43f0-9eb2-114d147acced',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7993,
#    'time_window_end': 8075,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 7993,
#       'SET': 8111,
#       'TRX ON': 7993,
#       'TRX OFF': 8111},
#      {'RISE': 8020, 'SET': 8250, 'TRX ON': 8020, 'TRX OFF': 8250},
#      {'RISE': 8047, 'SET': 8143, 'TRX ON': 8047, 'TRX OFF': 8143}],
#     'DSS-24': [{'RISE': 7993, 'SET': 8103, 'TRX ON': 7993, 'TRX OFF': 8103},
#      {'RISE': 8020, 'SET': 8153, 'TRX ON': 8020, 'TRX OFF': 8153},
#      {'RISE': 8047, 'SET': 8270, 'TRX ON': 8047, 'TRX OFF': 8270}],
#     'DSS-26': [{'RISE': 7993, 'SET': 8153, 'TRX ON': 7993, 'TRX OFF': 8153},
#      {'RISE': 8020, 'SET': 8178, 'TRX ON': 8020, 'TRX OFF': 8178},
#      {'RISE': 8047, 'SET': 8178, 'TRX ON': 8047, 'TRX OFF': 8178}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 101,
#    'duration_min': 101,
#    'resources': [['DSS-26']],
#    'track_id': '1ee3a402-8563-4fbb-a890-711f2c174064',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4342,
#    'time_window_end': 4428,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 4342,
#       'SET': 4530,
#       'TRX ON': 4342,
#       'TRX OFF': 4530},
#      {'RISE': 4370, 'SET': 4596, 'TRX ON': 4370, 'TRX OFF': 4596},
#      {'RISE': 4398, 'SET': 4622, 'TRX ON': 4398, 'TRX OFF': 4622}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 88,
#    'duration_min': 88,
#    'resources': [['DSS-26']],
#    'track_id': 'c1d63921-0683-4142-81d5-2a07599999df',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7639,
#    'time_window_end': 7712,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 7639,
#       'SET': 7851,
#       'TRX ON': 7639,
#       'TRX OFF': 7851},
#      {'RISE': 7663, 'SET': 7775, 'TRX ON': 7663, 'TRX OFF': 7775},
#      {'RISE': 7687, 'SET': 7917, 'TRX ON': 7687, 'TRX OFF': 7917}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 111,
#    'duration_min': 111,
#    'resources': [['DSS-54'], ['DSS-36'], ['DSS-24'], ['DSS-26']],
#    'track_id': '4099a83a-abc0-49a4-ae9c-8e7b450a6e68',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 8325,
#    'time_window_end': 8395,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 8325,
#       'SET': 8441,
#       'TRX ON': 8325,
#       'TRX OFF': 8441},
#      {'RISE': 8348, 'SET': 8463, 'TRX ON': 8348, 'TRX OFF': 8463},
#      {'RISE': 8371, 'SET': 8564, 'TRX ON': 8371, 'TRX OFF': 8564}],
#     'DSS-36': [{'RISE': 8325, 'SET': 8525, 'TRX ON': 8325, 'TRX OFF': 8525},
#      {'RISE': 8348, 'SET': 8497, 'TRX ON': 8348, 'TRX OFF': 8497},
#      {'RISE': 8371, 'SET': 8565, 'TRX ON': 8371, 'TRX OFF': 8565}],
#     'DSS-24': [{'RISE': 8325, 'SET': 8554, 'TRX ON': 8325, 'TRX OFF': 8554},
#      {'RISE': 8348, 'SET': 8448, 'TRX ON': 8348, 'TRX OFF': 8448},
#      {'RISE': 8371, 'SET': 8588, 'TRX ON': 8371, 'TRX OFF': 8588}],
#     'DSS-26': [{'RISE': 8325, 'SET': 8473, 'TRX ON': 8325, 'TRX OFF': 8473},
#      {'RISE': 8348, 'SET': 8490, 'TRX ON': 8348, 'TRX OFF': 8490},
#      {'RISE': 8371, 'SET': 8497, 'TRX ON': 8371, 'TRX OFF': 8497}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 87,
#    'duration_min': 87,
#    'resources': [['DSS-36'], ['DSS-24'], ['DSS-34'], ['DSS-54']],
#    'track_id': '831ba7c9-f088-4e65-97fc-3772c85042ef',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 769,
#    'time_window_end': 838,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 769,
#       'SET': 913,
#       'TRX ON': 769,
#       'TRX OFF': 913},
#      {'RISE': 792, 'SET': 996, 'TRX ON': 792, 'TRX OFF': 996},
#      {'RISE': 815, 'SET': 956, 'TRX ON': 815, 'TRX OFF': 956}],
#     'DSS-24': [{'RISE': 769, 'SET': 942, 'TRX ON': 769, 'TRX OFF': 942},
#      {'RISE': 792, 'SET': 977, 'TRX ON': 792, 'TRX OFF': 977},
#      {'RISE': 815, 'SET': 1016, 'TRX ON': 815, 'TRX OFF': 1016}],
#     'DSS-34': [{'RISE': 769, 'SET': 842, 'TRX ON': 769, 'TRX OFF': 842},
#      {'RISE': 792, 'SET': 874, 'TRX ON': 792, 'TRX OFF': 874},
#      {'RISE': 815, 'SET': 887, 'TRX ON': 815, 'TRX OFF': 887}],
#     'DSS-54': [{'RISE': 769, 'SET': 939, 'TRX ON': 769, 'TRX OFF': 939},
#      {'RISE': 792, 'SET': 920, 'TRX ON': 792, 'TRX OFF': 920},
#      {'RISE': 815, 'SET': 940, 'TRX ON': 815, 'TRX OFF': 940}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 97,
#    'duration_min': 97,
#    'resources': [['DSS-24'], ['DSS-36']],
#    'track_id': 'a9e98d35-178b-4bca-891b-1e3d6bab9510',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7869,
#    'time_window_end': 7948,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 7869,
#       'SET': 7958,
#       'TRX ON': 7869,
#       'TRX OFF': 7958},
#      {'RISE': 7895, 'SET': 8079, 'TRX ON': 7895, 'TRX OFF': 8079},
#      {'RISE': 7921, 'SET': 8022, 'TRX ON': 7921, 'TRX OFF': 8022}],
#     'DSS-36': [{'RISE': 7869, 'SET': 8004, 'TRX ON': 7869, 'TRX OFF': 8004},
#      {'RISE': 7895, 'SET': 8087, 'TRX ON': 7895, 'TRX OFF': 8087},
#      {'RISE': 7921, 'SET': 8092, 'TRX ON': 7921, 'TRX OFF': 8092}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 114,
#    'duration_min': 114,
#    'resources': [['DSS-36'], ['DSS-26'], ['DSS-24'], ['DSS-34']],
#    'track_id': '9b170502-b082-418c-a336-5e519c0b5c3b',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 914,
#    'time_window_end': 996,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 914,
#       'SET': 1043,
#       'TRX ON': 914,
#       'TRX OFF': 1043},
#      {'RISE': 941, 'SET': 1134, 'TRX ON': 941, 'TRX OFF': 1134},
#      {'RISE': 968, 'SET': 1189, 'TRX ON': 968, 'TRX OFF': 1189}],
#     'DSS-26': [{'RISE': 914, 'SET': 1105, 'TRX ON': 914, 'TRX OFF': 1105},
#      {'RISE': 941, 'SET': 1125, 'TRX ON': 941, 'TRX OFF': 1125},
#      {'RISE': 968, 'SET': 1190, 'TRX ON': 968, 'TRX OFF': 1190}],
#     'DSS-24': [{'RISE': 914, 'SET': 1104, 'TRX ON': 914, 'TRX OFF': 1104},
#      {'RISE': 941, 'SET': 1157, 'TRX ON': 941, 'TRX OFF': 1157},
#      {'RISE': 968, 'SET': 1171, 'TRX ON': 968, 'TRX OFF': 1171}],
#     'DSS-34': [{'RISE': 914, 'SET': 1062, 'TRX ON': 914, 'TRX OFF': 1062},
#      {'RISE': 941, 'SET': 1090, 'TRX ON': 941, 'TRX OFF': 1090},
#      {'RISE': 968, 'SET': 1150, 'TRX ON': 968, 'TRX OFF': 1150}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 92,
#    'duration_min': 92,
#    'resources': [['DSS-26'], ['DSS-36'], ['DSS-54']],
#    'track_id': '1bf9bab2-0078-4b85-a744-5e815b7abdae',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 6927,
#    'time_window_end': 7013,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 6927,
#       'SET': 7061,
#       'TRX ON': 6927,
#       'TRX OFF': 7061},
#      {'RISE': 6955, 'SET': 7173, 'TRX ON': 6955, 'TRX OFF': 7173},
#      {'RISE': 6983, 'SET': 7052, 'TRX ON': 6983, 'TRX OFF': 7052}],
#     'DSS-36': [{'RISE': 6927, 'SET': 7029, 'TRX ON': 6927, 'TRX OFF': 7029},
#      {'RISE': 6955, 'SET': 7133, 'TRX ON': 6955, 'TRX OFF': 7133},
#      {'RISE': 6983, 'SET': 7121, 'TRX ON': 6983, 'TRX OFF': 7121}],
#     'DSS-54': [{'RISE': 6927, 'SET': 7086, 'TRX ON': 6927, 'TRX OFF': 7086},
#      {'RISE': 6955, 'SET': 7157, 'TRX ON': 6955, 'TRX OFF': 7157},
#      {'RISE': 6983, 'SET': 7045, 'TRX ON': 6983, 'TRX OFF': 7045}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 112,
#    'duration_min': 112,
#    'resources': [['DSS-34'], ['DSS-36'], ['DSS-24'], ['DSS-54'], ['DSS-26']],
#    'track_id': '3fe2fcaf-a5c4-41ad-a661-2d716c2dde0d',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 251,
#    'time_window_end': 335,
#    'resource_vp_dict': {'DSS-34': [{'RISE': 251,
#       'SET': 400,
#       'TRX ON': 251,
#       'TRX OFF': 400},
#      {'RISE': 279, 'SET': 382, 'TRX ON': 279, 'TRX OFF': 382},
#      {'RISE': 307, 'SET': 459, 'TRX ON': 307, 'TRX OFF': 459}],
#     'DSS-36': [{'RISE': 251, 'SET': 380, 'TRX ON': 251, 'TRX OFF': 380},
#      {'RISE': 279, 'SET': 515, 'TRX ON': 279, 'TRX OFF': 515},
#      {'RISE': 307, 'SET': 532, 'TRX ON': 307, 'TRX OFF': 532}],
#     'DSS-24': [{'RISE': 251, 'SET': 470, 'TRX ON': 251, 'TRX OFF': 470},
#      {'RISE': 279, 'SET': 449, 'TRX ON': 279, 'TRX OFF': 449},
#      {'RISE': 307, 'SET': 405, 'TRX ON': 307, 'TRX OFF': 405}],
#     'DSS-54': [{'RISE': 251, 'SET': 485, 'TRX ON': 251, 'TRX OFF': 485},
#      {'RISE': 279, 'SET': 504, 'TRX ON': 279, 'TRX OFF': 504},
#      {'RISE': 307, 'SET': 497, 'TRX ON': 307, 'TRX OFF': 497}],
#     'DSS-26': [{'RISE': 251, 'SET': 357, 'TRX ON': 251, 'TRX OFF': 357},
#      {'RISE': 279, 'SET': 444, 'TRX ON': 279, 'TRX OFF': 444},
#      {'RISE': 307, 'SET': 411, 'TRX ON': 307, 'TRX OFF': 411}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 112,
#    'duration_min': 112,
#    'resources': [['DSS-36']],
#    'track_id': '1452ac04-99ac-41bb-bae6-908f8e75aeda',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4740,
#    'time_window_end': 4815,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 4740,
#       'SET': 4907,
#       'TRX ON': 4740,
#       'TRX OFF': 4907},
#      {'RISE': 4765, 'SET': 4889, 'TRX ON': 4765, 'TRX OFF': 4889},
#      {'RISE': 4790, 'SET': 4973, 'TRX ON': 4790, 'TRX OFF': 4973}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 67,
#    'duration_min': 67,
#    'resources': [['DSS-54'], ['DSS-36'], ['DSS-34'], ['DSS-24'], ['DSS-26']],
#    'track_id': '1325070a-08dd-4cee-b4c3-9f2dba8e3994',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 3150,
#    'time_window_end': 3218,
#    'resource_vp_dict': {'DSS-54': [{'RISE': 3150,
#       'SET': 3374,
#       'TRX ON': 3150,
#       'TRX OFF': 3374},
#      {'RISE': 3172, 'SET': 3376, 'TRX ON': 3172, 'TRX OFF': 3376},
#      {'RISE': 3194, 'SET': 3323, 'TRX ON': 3194, 'TRX OFF': 3323}],
#     'DSS-36': [{'RISE': 3150, 'SET': 3232, 'TRX ON': 3150, 'TRX OFF': 3232},
#      {'RISE': 3172, 'SET': 3335, 'TRX ON': 3172, 'TRX OFF': 3335},
#      {'RISE': 3194, 'SET': 3392, 'TRX ON': 3194, 'TRX OFF': 3392}],
#     'DSS-34': [{'RISE': 3150, 'SET': 3258, 'TRX ON': 3150, 'TRX OFF': 3258},
#      {'RISE': 3172, 'SET': 3292, 'TRX ON': 3172, 'TRX OFF': 3292},
#      {'RISE': 3194, 'SET': 3299, 'TRX ON': 3194, 'TRX OFF': 3299}],
#     'DSS-24': [{'RISE': 3150, 'SET': 3247, 'TRX ON': 3150, 'TRX OFF': 3247},
#      {'RISE': 3172, 'SET': 3398, 'TRX ON': 3172, 'TRX OFF': 3398},
#      {'RISE': 3194, 'SET': 3395, 'TRX ON': 3194, 'TRX OFF': 3395}],
#     'DSS-26': [{'RISE': 3150, 'SET': 3323, 'TRX ON': 3150, 'TRX OFF': 3323},
#      {'RISE': 3172, 'SET': 3359, 'TRX ON': 3172, 'TRX OFF': 3359},
#      {'RISE': 3194, 'SET': 3430, 'TRX ON': 3194, 'TRX OFF': 3430}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 60,
#    'duration_min': 60,
#    'resources': [['DSS-24'], ['DSS-34'], ['DSS-54'], ['DSS-36']],
#    'track_id': '501f8708-0783-4d20-9064-1d91eae0b48f',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 6977,
#    'time_window_end': 7061,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 6977,
#       'SET': 7057,
#       'TRX ON': 6977,
#       'TRX OFF': 7057},
#      {'RISE': 7005, 'SET': 7213, 'TRX ON': 7005, 'TRX OFF': 7213},
#      {'RISE': 7033, 'SET': 7194, 'TRX ON': 7033, 'TRX OFF': 7194}],
#     'DSS-34': [{'RISE': 6977, 'SET': 7128, 'TRX ON': 6977, 'TRX OFF': 7128},
#      {'RISE': 7005, 'SET': 7092, 'TRX ON': 7005, 'TRX OFF': 7092},
#      {'RISE': 7033, 'SET': 7166, 'TRX ON': 7033, 'TRX OFF': 7166}],
#     'DSS-54': [{'RISE': 6977, 'SET': 7159, 'TRX ON': 6977, 'TRX OFF': 7159},
#      {'RISE': 7005, 'SET': 7139, 'TRX ON': 7005, 'TRX OFF': 7139},
#      {'RISE': 7033, 'SET': 7235, 'TRX ON': 7033, 'TRX OFF': 7235}],
#     'DSS-36': [{'RISE': 6977, 'SET': 7185, 'TRX ON': 6977, 'TRX OFF': 7185},
#      {'RISE': 7005, 'SET': 7214, 'TRX ON': 7005, 'TRX OFF': 7214},
#      {'RISE': 7033, 'SET': 7180, 'TRX ON': 7033, 'TRX OFF': 7180}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 92,
#    'duration_min': 92,
#    'resources': [['DSS-26'], ['DSS-36'], ['DSS-24'], ['DSS-54']],
#    'track_id': '4b6a8f24-52c7-427e-b4b3-8cd3cccf2646',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 8534,
#    'time_window_end': 8621,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 8534,
#       'SET': 8760,
#       'TRX ON': 8534,
#       'TRX OFF': 8760},
#      {'RISE': 8563, 'SET': 8661, 'TRX ON': 8563, 'TRX OFF': 8661},
#      {'RISE': 8592, 'SET': 8705, 'TRX ON': 8592, 'TRX OFF': 8705}],
#     'DSS-36': [{'RISE': 8534, 'SET': 8660, 'TRX ON': 8534, 'TRX OFF': 8660},
#      {'RISE': 8563, 'SET': 8634, 'TRX ON': 8563, 'TRX OFF': 8634},
#      {'RISE': 8592, 'SET': 8777, 'TRX ON': 8592, 'TRX OFF': 8777}],
#     'DSS-24': [{'RISE': 8534, 'SET': 8691, 'TRX ON': 8534, 'TRX OFF': 8691},
#      {'RISE': 8563, 'SET': 8745, 'TRX ON': 8563, 'TRX OFF': 8745},
#      {'RISE': 8592, 'SET': 8684, 'TRX ON': 8592, 'TRX OFF': 8684}],
#     'DSS-54': [{'RISE': 8534, 'SET': 8645, 'TRX ON': 8534, 'TRX OFF': 8645},
#      {'RISE': 8563, 'SET': 8664, 'TRX ON': 8563, 'TRX OFF': 8664},
#      {'RISE': 8592, 'SET': 8667, 'TRX ON': 8592, 'TRX OFF': 8667}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 98,
#    'duration_min': 98,
#    'resources': [['DSS-26']],
#    'track_id': 'd6132510-6503-4e6a-9ca6-c56ac4dae9a2',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5071,
#    'time_window_end': 5134,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 5071,
#       'SET': 5212,
#       'TRX ON': 5071,
#       'TRX OFF': 5212},
#      {'RISE': 5092, 'SET': 5285, 'TRX ON': 5092, 'TRX OFF': 5285},
#      {'RISE': 5113, 'SET': 5201, 'TRX ON': 5113, 'TRX OFF': 5201}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 85,
#    'duration_min': 85,
#    'resources': [['DSS-26'], ['DSS-34'], ['DSS-54'], ['DSS-36']],
#    'track_id': '5c4e7f0e-e3f2-4763-98cb-92b20f5391c2',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 2270,
#    'time_window_end': 2345,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 2270,
#       'SET': 2425,
#       'TRX ON': 2270,
#       'TRX OFF': 2425},
#      {'RISE': 2295, 'SET': 2420, 'TRX ON': 2295, 'TRX OFF': 2420},
#      {'RISE': 2320, 'SET': 2445, 'TRX ON': 2320, 'TRX OFF': 2445}],
#     'DSS-34': [{'RISE': 2270, 'SET': 2331, 'TRX ON': 2270, 'TRX OFF': 2331},
#      {'RISE': 2295, 'SET': 2500, 'TRX ON': 2295, 'TRX OFF': 2500},
#      {'RISE': 2320, 'SET': 2468, 'TRX ON': 2320, 'TRX OFF': 2468}],
#     'DSS-54': [{'RISE': 2270, 'SET': 2394, 'TRX ON': 2270, 'TRX OFF': 2394},
#      {'RISE': 2295, 'SET': 2430, 'TRX ON': 2295, 'TRX OFF': 2430},
#      {'RISE': 2320, 'SET': 2418, 'TRX ON': 2320, 'TRX OFF': 2418}],
#     'DSS-36': [{'RISE': 2270, 'SET': 2348, 'TRX ON': 2270, 'TRX OFF': 2348},
#      {'RISE': 2295, 'SET': 2448, 'TRX ON': 2295, 'TRX OFF': 2448},
#      {'RISE': 2320, 'SET': 2538, 'TRX ON': 2320, 'TRX OFF': 2538}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 60,
#    'duration_min': 60,
#    'resources': [['DSS-26'], ['DSS-36'], ['DSS-34']],
#    'track_id': 'b5fd5d08-e8ca-4cd3-875b-8ffb880a03e1',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4504,
#    'time_window_end': 4580,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 4504,
#       'SET': 4721,
#       'TRX ON': 4504,
#       'TRX OFF': 4721},
#      {'RISE': 4529, 'SET': 4661, 'TRX ON': 4529, 'TRX OFF': 4661},
#      {'RISE': 4554, 'SET': 4705, 'TRX ON': 4554, 'TRX OFF': 4705}],
#     'DSS-36': [{'RISE': 4504, 'SET': 4644, 'TRX ON': 4504, 'TRX OFF': 4644},
#      {'RISE': 4529, 'SET': 4640, 'TRX ON': 4529, 'TRX OFF': 4640},
#      {'RISE': 4554, 'SET': 4760, 'TRX ON': 4554, 'TRX OFF': 4760}],
#     'DSS-34': [{'RISE': 4504, 'SET': 4692, 'TRX ON': 4504, 'TRX OFF': 4692},
#      {'RISE': 4529, 'SET': 4609, 'TRX ON': 4529, 'TRX OFF': 4609},
#      {'RISE': 4554, 'SET': 4615, 'TRX ON': 4554, 'TRX OFF': 4615}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 78,
#    'duration_min': 78,
#    'resources': [['DSS-34']],
#    'track_id': 'f95294a8-f55f-4c02-bdb5-6d0f6ee3a024',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 9287,
#    'time_window_end': 9362,
#    'resource_vp_dict': {'DSS-34': [{'RISE': 9287,
#       'SET': 9425,
#       'TRX ON': 9287,
#       'TRX OFF': 9425},
#      {'RISE': 9312, 'SET': 9456, 'TRX ON': 9312, 'TRX OFF': 9456},
#      {'RISE': 9337, 'SET': 9563, 'TRX ON': 9337, 'TRX OFF': 9563}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 72,
#    'duration_min': 72,
#    'resources': [['DSS-24'], ['DSS-34'], ['DSS-54'], ['DSS-26'], ['DSS-36']],
#    'track_id': '57a46591-4246-470d-8542-e5616c42d71d',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4290,
#    'time_window_end': 4358,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 4290,
#       'SET': 4513,
#       'TRX ON': 4290,
#       'TRX OFF': 4513},
#      {'RISE': 4312, 'SET': 4376, 'TRX ON': 4312, 'TRX OFF': 4376},
#      {'RISE': 4334, 'SET': 4545, 'TRX ON': 4334, 'TRX OFF': 4545}],
#     'DSS-34': [{'RISE': 4290, 'SET': 4502, 'TRX ON': 4290, 'TRX OFF': 4502},
#      {'RISE': 4312, 'SET': 4530, 'TRX ON': 4312, 'TRX OFF': 4530},
#      {'RISE': 4334, 'SET': 4541, 'TRX ON': 4334, 'TRX OFF': 4541}],
#     'DSS-54': [{'RISE': 4290, 'SET': 4360, 'TRX ON': 4290, 'TRX OFF': 4360},
#      {'RISE': 4312, 'SET': 4467, 'TRX ON': 4312, 'TRX OFF': 4467},
#      {'RISE': 4334, 'SET': 4432, 'TRX ON': 4334, 'TRX OFF': 4432}],
#     'DSS-26': [{'RISE': 4290, 'SET': 4366, 'TRX ON': 4290, 'TRX OFF': 4366},
#      {'RISE': 4312, 'SET': 4542, 'TRX ON': 4312, 'TRX OFF': 4542},
#      {'RISE': 4334, 'SET': 4472, 'TRX ON': 4334, 'TRX OFF': 4472}],
#     'DSS-36': [{'RISE': 4290, 'SET': 4438, 'TRX ON': 4290, 'TRX OFF': 4438},
#      {'RISE': 4312, 'SET': 4538, 'TRX ON': 4312, 'TRX OFF': 4538},
#      {'RISE': 4334, 'SET': 4509, 'TRX ON': 4334, 'TRX OFF': 4509}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 76,
#    'duration_min': 76,
#    'resources': [['DSS-24'], ['DSS-36']],
#    'track_id': 'd84e8e02-9789-42df-b86a-680d02b2356c',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 9089,
#    'time_window_end': 9155,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 9089,
#       'SET': 9176,
#       'TRX ON': 9089,
#       'TRX OFF': 9176},
#      {'RISE': 9111, 'SET': 9215, 'TRX ON': 9111, 'TRX OFF': 9215},
#      {'RISE': 9133, 'SET': 9300, 'TRX ON': 9133, 'TRX OFF': 9300}],
#     'DSS-36': [{'RISE': 9089, 'SET': 9183, 'TRX ON': 9089, 'TRX OFF': 9183},
#      {'RISE': 9111, 'SET': 9295, 'TRX ON': 9111, 'TRX OFF': 9295},
#      {'RISE': 9133, 'SET': 9228, 'TRX ON': 9133, 'TRX OFF': 9228}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 60,
#    'duration_min': 60,
#    'resources': [['DSS-24'], ['DSS-34']],
#    'track_id': 'e96c9812-332c-409e-b9a9-c9ea6356ad76',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4848,
#    'time_window_end': 4922,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 4848,
#       'SET': 5055,
#       'TRX ON': 4848,
#       'TRX OFF': 5055},
#      {'RISE': 4872, 'SET': 5027, 'TRX ON': 4872, 'TRX OFF': 5027},
#      {'RISE': 4896, 'SET': 5083, 'TRX ON': 4896, 'TRX OFF': 5083}],
#     'DSS-34': [{'RISE': 4848, 'SET': 5005, 'TRX ON': 4848, 'TRX OFF': 5005},
#      {'RISE': 4872, 'SET': 5073, 'TRX ON': 4872, 'TRX OFF': 5073},
#      {'RISE': 4896, 'SET': 5061, 'TRX ON': 4896, 'TRX OFF': 5061}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 69,
#    'duration_min': 69,
#    'resources': [['DSS-34']],
#    'track_id': '7153b58d-b87d-4a96-b18c-d00b91acda1b',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5565,
#    'time_window_end': 5649,
#    'resource_vp_dict': {'DSS-34': [{'RISE': 5565,
#       'SET': 5724,
#       'TRX ON': 5565,
#       'TRX OFF': 5724},
#      {'RISE': 5593, 'SET': 5747, 'TRX ON': 5593, 'TRX OFF': 5747},
#      {'RISE': 5621, 'SET': 5844, 'TRX ON': 5621, 'TRX OFF': 5844}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 110,
#    'duration_min': 110,
#    'resources': [['DSS-26'], ['DSS-54'], ['DSS-24']],
#    'track_id': 'f2111c33-fab7-4e14-99da-a1eedeb60c6c',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 221,
#    'time_window_end': 295,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 221,
#       'SET': 437,
#       'TRX ON': 221,
#       'TRX OFF': 437},
#      {'RISE': 245, 'SET': 363, 'TRX ON': 245, 'TRX OFF': 363},
#      {'RISE': 269, 'SET': 435, 'TRX ON': 269, 'TRX OFF': 435}],
#     'DSS-54': [{'RISE': 221, 'SET': 411, 'TRX ON': 221, 'TRX OFF': 411},
#      {'RISE': 245, 'SET': 376, 'TRX ON': 245, 'TRX OFF': 376},
#      {'RISE': 269, 'SET': 329, 'TRX ON': 269, 'TRX OFF': 329}],
#     'DSS-24': [{'RISE': 221, 'SET': 343, 'TRX ON': 221, 'TRX OFF': 343},
#      {'RISE': 245, 'SET': 441, 'TRX ON': 245, 'TRX OFF': 441},
#      {'RISE': 269, 'SET': 508, 'TRX ON': 269, 'TRX OFF': 508}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 79,
#    'duration_min': 79,
#    'resources': [['DSS-26'], ['DSS-36'], ['DSS-54']],
#    'track_id': 'ef5c3953-3b48-4da4-9d28-af6e2392bd07',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 3305,
#    'time_window_end': 3387,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 3305,
#       'SET': 3385,
#       'TRX ON': 3305,
#       'TRX OFF': 3385},
#      {'RISE': 3332, 'SET': 3451, 'TRX ON': 3332, 'TRX OFF': 3451},
#      {'RISE': 3359, 'SET': 3539, 'TRX ON': 3359, 'TRX OFF': 3539}],
#     'DSS-36': [{'RISE': 3305, 'SET': 3441, 'TRX ON': 3305, 'TRX OFF': 3441},
#      {'RISE': 3332, 'SET': 3443, 'TRX ON': 3332, 'TRX OFF': 3443},
#      {'RISE': 3359, 'SET': 3548, 'TRX ON': 3359, 'TRX OFF': 3548}],
#     'DSS-54': [{'RISE': 3305, 'SET': 3370, 'TRX ON': 3305, 'TRX OFF': 3370},
#      {'RISE': 3332, 'SET': 3506, 'TRX ON': 3332, 'TRX OFF': 3506},
#      {'RISE': 3359, 'SET': 3493, 'TRX ON': 3359, 'TRX OFF': 3493}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 97,
#    'duration_min': 97,
#    'resources': [['DSS-26'], ['DSS-24']],
#    'track_id': '9a822858-21dd-4d74-a4c5-f84da3df1044',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 4861,
#    'time_window_end': 4937,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 4861,
#       'SET': 4968,
#       'TRX ON': 4861,
#       'TRX OFF': 4968},
#      {'RISE': 4886, 'SET': 5024, 'TRX ON': 4886, 'TRX OFF': 5024},
#      {'RISE': 4911, 'SET': 5039, 'TRX ON': 4911, 'TRX OFF': 5039}],
#     'DSS-24': [{'RISE': 4861, 'SET': 5015, 'TRX ON': 4861, 'TRX OFF': 5015},
#      {'RISE': 4886, 'SET': 4995, 'TRX ON': 4886, 'TRX OFF': 4995},
#      {'RISE': 4911, 'SET': 5106, 'TRX ON': 4911, 'TRX OFF': 5106}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 119,
#    'duration_min': 119,
#    'resources': [['DSS-34'], ['DSS-54'], ['DSS-24'], ['DSS-36']],
#    'track_id': '4185c89d-a2d9-4d1a-a501-2eafbb5f3b2f',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 2664,
#    'time_window_end': 2727,
#    'resource_vp_dict': {'DSS-34': [{'RISE': 2664,
#       'SET': 2765,
#       'TRX ON': 2664,
#       'TRX OFF': 2765},
#      {'RISE': 2685, 'SET': 2781, 'TRX ON': 2685, 'TRX OFF': 2781},
#      {'RISE': 2706, 'SET': 2846, 'TRX ON': 2706, 'TRX OFF': 2846}],
#     'DSS-54': [{'RISE': 2664, 'SET': 2752, 'TRX ON': 2664, 'TRX OFF': 2752},
#      {'RISE': 2685, 'SET': 2802, 'TRX ON': 2685, 'TRX OFF': 2802},
#      {'RISE': 2706, 'SET': 2930, 'TRX ON': 2706, 'TRX OFF': 2930}],
#     'DSS-24': [{'RISE': 2664, 'SET': 2803, 'TRX ON': 2664, 'TRX OFF': 2803},
#      {'RISE': 2685, 'SET': 2748, 'TRX ON': 2685, 'TRX OFF': 2748},
#      {'RISE': 2706, 'SET': 2902, 'TRX ON': 2706, 'TRX OFF': 2902}],
#     'DSS-36': [{'RISE': 2664, 'SET': 2874, 'TRX ON': 2664, 'TRX OFF': 2874},
#      {'RISE': 2685, 'SET': 2879, 'TRX ON': 2685, 'TRX OFF': 2879},
#      {'RISE': 2706, 'SET': 2862, 'TRX ON': 2706, 'TRX OFF': 2862}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 114,
#    'duration_min': 114,
#    'resources': [['DSS-24'], ['DSS-34'], ['DSS-54'], ['DSS-26']],
#    'track_id': 'c42c0a6d-7187-4423-bed9-89264a28c41c',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 8564,
#    'time_window_end': 8653,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 8564,
#       'SET': 8658,
#       'TRX ON': 8564,
#       'TRX OFF': 8658},
#      {'RISE': 8593, 'SET': 8753, 'TRX ON': 8593, 'TRX OFF': 8753},
#      {'RISE': 8622, 'SET': 8685, 'TRX ON': 8622, 'TRX OFF': 8685}],
#     'DSS-34': [{'RISE': 8564, 'SET': 8706, 'TRX ON': 8564, 'TRX OFF': 8706},
#      {'RISE': 8593, 'SET': 8751, 'TRX ON': 8593, 'TRX OFF': 8751},
#      {'RISE': 8622, 'SET': 8721, 'TRX ON': 8622, 'TRX OFF': 8721}],
#     'DSS-54': [{'RISE': 8564, 'SET': 8652, 'TRX ON': 8564, 'TRX OFF': 8652},
#      {'RISE': 8593, 'SET': 8769, 'TRX ON': 8593, 'TRX OFF': 8769},
#      {'RISE': 8622, 'SET': 8725, 'TRX ON': 8622, 'TRX OFF': 8725}],
#     'DSS-26': [{'RISE': 8564, 'SET': 8754, 'TRX ON': 8564, 'TRX OFF': 8754},
#      {'RISE': 8593, 'SET': 8705, 'TRX ON': 8593, 'TRX OFF': 8705},
#      {'RISE': 8622, 'SET': 8687, 'TRX ON': 8622, 'TRX OFF': 8687}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 77,
#    'duration_min': 77,
#    'resources': [['DSS-26'], ['DSS-24'], ['DSS-34']],
#    'track_id': '7b9ac88d-e8c7-4b23-bf33-2340204458d0',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5640,
#    'time_window_end': 5715,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 5640,
#       'SET': 5831,
#       'TRX ON': 5640,
#       'TRX OFF': 5831},
#      {'RISE': 5665, 'SET': 5790, 'TRX ON': 5665, 'TRX OFF': 5790},
#      {'RISE': 5690, 'SET': 5898, 'TRX ON': 5690, 'TRX OFF': 5898}],
#     'DSS-24': [{'RISE': 5640, 'SET': 5786, 'TRX ON': 5640, 'TRX OFF': 5786},
#      {'RISE': 5665, 'SET': 5729, 'TRX ON': 5665, 'TRX OFF': 5729},
#      {'RISE': 5690, 'SET': 5852, 'TRX ON': 5690, 'TRX OFF': 5852}],
#     'DSS-34': [{'RISE': 5640, 'SET': 5706, 'TRX ON': 5640, 'TRX OFF': 5706},
#      {'RISE': 5665, 'SET': 5732, 'TRX ON': 5665, 'TRX OFF': 5732},
#      {'RISE': 5690, 'SET': 5820, 'TRX ON': 5690, 'TRX OFF': 5820}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 103,
#    'duration_min': 103,
#    'resources': [['DSS-24'], ['DSS-34'], ['DSS-36'], ['DSS-54'], ['DSS-26']],
#    'track_id': 'ae2bb722-ed8d-4ece-9c18-be614b603498',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 7368,
#    'time_window_end': 7446,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 7368,
#       'SET': 7507,
#       'TRX ON': 7368,
#       'TRX OFF': 7507},
#      {'RISE': 7394, 'SET': 7614, 'TRX ON': 7394, 'TRX OFF': 7614},
#      {'RISE': 7420, 'SET': 7504, 'TRX ON': 7420, 'TRX OFF': 7504}],
#     'DSS-34': [{'RISE': 7368, 'SET': 7556, 'TRX ON': 7368, 'TRX OFF': 7556},
#      {'RISE': 7394, 'SET': 7469, 'TRX ON': 7394, 'TRX OFF': 7469},
#      {'RISE': 7420, 'SET': 7494, 'TRX ON': 7420, 'TRX OFF': 7494}],
#     'DSS-36': [{'RISE': 7368, 'SET': 7516, 'TRX ON': 7368, 'TRX OFF': 7516},
#      {'RISE': 7394, 'SET': 7504, 'TRX ON': 7394, 'TRX OFF': 7504},
#      {'RISE': 7420, 'SET': 7527, 'TRX ON': 7420, 'TRX OFF': 7527}],
#     'DSS-54': [{'RISE': 7368, 'SET': 7578, 'TRX ON': 7368, 'TRX OFF': 7578},
#      {'RISE': 7394, 'SET': 7501, 'TRX ON': 7394, 'TRX OFF': 7501},
#      {'RISE': 7420, 'SET': 7609, 'TRX ON': 7420, 'TRX OFF': 7609}],
#     'DSS-26': [{'RISE': 7368, 'SET': 7482, 'TRX ON': 7368, 'TRX OFF': 7482},
#      {'RISE': 7394, 'SET': 7511, 'TRX ON': 7394, 'TRX OFF': 7511},
#      {'RISE': 7420, 'SET': 7541, 'TRX ON': 7420, 'TRX OFF': 7541}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 72,
#    'duration_min': 72,
#    'resources': [['DSS-34'], ['DSS-54']],
#    'track_id': '99bb0c05-9cca-4a9d-9edb-ea410a9ac970',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5941,
#    'time_window_end': 6007,
#    'resource_vp_dict': {'DSS-34': [{'RISE': 5941,
#       'SET': 6148,
#       'TRX ON': 5941,
#       'TRX OFF': 6148},
#      {'RISE': 5963, 'SET': 6092, 'TRX ON': 5963, 'TRX OFF': 6092},
#      {'RISE': 5985, 'SET': 6125, 'TRX ON': 5985, 'TRX OFF': 6125}],
#     'DSS-54': [{'RISE': 5941, 'SET': 6015, 'TRX ON': 5941, 'TRX OFF': 6015},
#      {'RISE': 5963, 'SET': 6117, 'TRX ON': 5963, 'TRX OFF': 6117},
#      {'RISE': 5985, 'SET': 6193, 'TRX ON': 5985, 'TRX OFF': 6193}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 75,
#    'duration_min': 75,
#    'resources': [['DSS-24']],
#    'track_id': 'ddaddf2f-c5df-4275-a660-d42f87b83620',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 856,
#    'time_window_end': 920,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 856,
#       'SET': 1043,
#       'TRX ON': 856,
#       'TRX OFF': 1043},
#      {'RISE': 877, 'SET': 1052, 'TRX ON': 877, 'TRX OFF': 1052},
#      {'RISE': 898, 'SET': 1114, 'TRX ON': 898, 'TRX OFF': 1114}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 75,
#    'duration_min': 75,
#    'resources': [['DSS-24'], ['DSS-36'], ['DSS-26']],
#    'track_id': '1d6ab74e-8a02-490d-ba04-4a53b6f29faa',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5074,
#    'time_window_end': 5159,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 5074,
#       'SET': 5194,
#       'TRX ON': 5074,
#       'TRX OFF': 5194},
#      {'RISE': 5102, 'SET': 5244, 'TRX ON': 5102, 'TRX OFF': 5244},
#      {'RISE': 5130, 'SET': 5246, 'TRX ON': 5130, 'TRX OFF': 5246}],
#     'DSS-36': [{'RISE': 5074, 'SET': 5274, 'TRX ON': 5074, 'TRX OFF': 5274},
#      {'RISE': 5102, 'SET': 5284, 'TRX ON': 5102, 'TRX OFF': 5284},
#      {'RISE': 5130, 'SET': 5190, 'TRX ON': 5130, 'TRX OFF': 5190}],
#     'DSS-26': [{'RISE': 5074, 'SET': 5310, 'TRX ON': 5074, 'TRX OFF': 5310},
#      {'RISE': 5102, 'SET': 5162, 'TRX ON': 5102, 'TRX OFF': 5162},
#      {'RISE': 5130, 'SET': 5219, 'TRX ON': 5130, 'TRX OFF': 5219}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 101,
#    'duration_min': 101,
#    'resources': [['DSS-36'], ['DSS-34']],
#    'track_id': '84546768-2bad-45e1-ac2f-a325b64d653f',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 1276,
#    'time_window_end': 1358,
#    'resource_vp_dict': {'DSS-36': [{'RISE': 1276,
#       'SET': 1509,
#       'TRX ON': 1276,
#       'TRX OFF': 1509},
#      {'RISE': 1303, 'SET': 1474, 'TRX ON': 1303, 'TRX OFF': 1474},
#      {'RISE': 1330, 'SET': 1510, 'TRX ON': 1330, 'TRX OFF': 1510}],
#     'DSS-34': [{'RISE': 1276, 'SET': 1451, 'TRX ON': 1276, 'TRX OFF': 1451},
#      {'RISE': 1303, 'SET': 1527, 'TRX ON': 1303, 'TRX OFF': 1527},
#      {'RISE': 1330, 'SET': 1568, 'TRX ON': 1330, 'TRX OFF': 1568}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 91,
#    'duration_min': 91,
#    'resources': [['DSS-24'], ['DSS-54'], ['DSS-26'], ['DSS-34']],
#    'track_id': '45233be0-e8f7-4a96-aa7f-aca6cd98456d',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 5790,
#    'time_window_end': 5877,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 5790,
#       'SET': 5864,
#       'TRX ON': 5790,
#       'TRX OFF': 5864},
#      {'RISE': 5819, 'SET': 5931, 'TRX ON': 5819, 'TRX OFF': 5931},
#      {'RISE': 5848, 'SET': 5935, 'TRX ON': 5848, 'TRX OFF': 5935}],
#     'DSS-54': [{'RISE': 5790, 'SET': 6019, 'TRX ON': 5790, 'TRX OFF': 6019},
#      {'RISE': 5819, 'SET': 6025, 'TRX ON': 5819, 'TRX OFF': 6025},
#      {'RISE': 5848, 'SET': 5993, 'TRX ON': 5848, 'TRX OFF': 5993}],
#     'DSS-26': [{'RISE': 5790, 'SET': 5956, 'TRX ON': 5790, 'TRX OFF': 5956},
#      {'RISE': 5819, 'SET': 5986, 'TRX ON': 5819, 'TRX OFF': 5986},
#      {'RISE': 5848, 'SET': 5919, 'TRX ON': 5848, 'TRX OFF': 5919}],
#     'DSS-34': [{'RISE': 5790, 'SET': 5890, 'TRX ON': 5790, 'TRX OFF': 5890},
#      {'RISE': 5819, 'SET': 5964, 'TRX ON': 5819, 'TRX OFF': 5964},
#      {'RISE': 5848, 'SET': 5912, 'TRX ON': 5848, 'TRX OFF': 5912}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 60,
#    'duration_min': 60,
#    'resources': [['DSS-24'], ['DSS-34'], ['DSS-26'], ['DSS-36']],
#    'track_id': '39d7f6e9-938e-4dfd-89c3-80958740f57a',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 8410,
#    'time_window_end': 8487,
#    'resource_vp_dict': {'DSS-24': [{'RISE': 8410,
#       'SET': 8627,
#       'TRX ON': 8410,
#       'TRX OFF': 8627},
#      {'RISE': 8435, 'SET': 8656, 'TRX ON': 8435, 'TRX OFF': 8656},
#      {'RISE': 8460, 'SET': 8664, 'TRX ON': 8460, 'TRX OFF': 8664}],
#     'DSS-34': [{'RISE': 8410, 'SET': 8495, 'TRX ON': 8410, 'TRX OFF': 8495},
#      {'RISE': 8435, 'SET': 8646, 'TRX ON': 8435, 'TRX OFF': 8646},
#      {'RISE': 8460, 'SET': 8637, 'TRX ON': 8460, 'TRX OFF': 8637}],
#     'DSS-26': [{'RISE': 8410, 'SET': 8492, 'TRX ON': 8410, 'TRX OFF': 8492},
#      {'RISE': 8435, 'SET': 8505, 'TRX ON': 8435, 'TRX OFF': 8505},
#      {'RISE': 8460, 'SET': 8684, 'TRX ON': 8460, 'TRX OFF': 8684}],
#     'DSS-36': [{'RISE': 8410, 'SET': 8560, 'TRX ON': 8410, 'TRX OFF': 8560},
#      {'RISE': 8435, 'SET': 8621, 'TRX ON': 8435, 'TRX OFF': 8621},
#      {'RISE': 8460, 'SET': 8654, 'TRX ON': 8460, 'TRX OFF': 8654}]}},
#   {'subject': 521,
#    'user': '521_0',
#    'week': 10,
#    'year': 2018,
#    'duration': 71,
#    'duration_min': 71,
#    'resources': [['DSS-26'], ['DSS-24'], ['DSS-36'], ['DSS-34'], ['DSS-54']],
#    'track_id': '49ddc97b-ea76-45a0-bde0-3593bc7ad7fb',
#    'setup_time': 60,
#    'teardown_time': 15,
#    'time_window_start': 1071,
#    'time_window_end': 1147,
#    'resource_vp_dict': {'DSS-26': [{'RISE': 1071,
#       'SET': 1306,
#       'TRX ON': 1071,
#       'TRX OFF': 1306},
#      {'RISE': 1096, 'SET': 1318, 'TRX ON': 1096, 'TRX OFF': 1318},
#      {'RISE': 1121, 'SET': 1290, 'TRX ON': 1121, 'TRX OFF': 1290}],
#     'DSS-24': [{'RISE': 1071, 'SET': 1268, 'TRX ON': 1071, 'TRX OFF': 1268},
#      {'RISE': 1096, 'SET': 1224, 'TRX ON': 1096, 'TRX OFF': 1224},
#      {'RISE': 1121, 'SET': 1284, 'TRX ON': 1121, 'TRX OFF': 1284}],
#     'DSS-36': [{'RISE': 1071, 'SET': 1183, 'TRX ON': 1071, 'TRX OFF': 1183},
#      {'RISE': 1096, 'SET': 1286, 'TRX ON': 1096, 'TRX OFF': 1286},
#      {'RISE': 1121, 'SET': 1193, 'TRX ON': 1121, 'TRX OFF': 1193}],
#     'DSS-34': [{'RISE': 1071, 'SET': 1153, 'TRX ON': 1071, 'TRX OFF': 1153},
#      {'RISE': 1096, 'SET': 1285, 'TRX ON': 1096, 'TRX OFF': 1285},
#      {'RISE': 1121, 'SET': 1207, 'TRX ON': 1121, 'TRX OFF': 1207}],
#     'DSS-54': [{'RISE': 1071, 'SET': 1167, 'TRX ON': 1071, 'TRX OFF': 1167},
#      {'RISE': 1096, 'SET': 1197, 'TRX ON': 1096, 'TRX OFF': 1197},
#      {'RISE': 1121, 'SET': 1182, 'TRX ON': 1121, 'TRX OFF': 1182}]}}]}

# %%
data = ''''
Antenna: DSS-24
Value: 1
Label: 2523
start (0.00/0.00) -> d9133ba9-0ce8-448a-b5df-932040dac4c8 (695.00/767.00) -> 3f9fa9e4-068b-4133-a607-146fd4287eaa (1236.00/1301.00) -> 92f6d1e8-ec2b-4252-901f-018ea971de22 (2267.00/2349.00) -> 7abb3922-10e3-41ac-a676-ce3e0d7b2b15 (2650.00/2746.00) -> b35ca6b3-798d-42b8-8d3e-b4885a007487 (6487.00/6557.00) -> 5e6b0e72-4763-49ac-8e79-840efece847f (6696.00/6766.00) -> 80a1a8da-00b2-4ec9-ae9c-9c903d59e49b (6841.00/6919.00) -> 458bd992-2291-471d-95c1-aadd1b725e72 (7240.00/7330.00) -> 75fc31e1-ab46-4999-9df8-4ecc3a868bac (8158.00/8224.00) -> faf65604-c3ad-4263-b4d5-02bd190a38e2 (8865.00/8912.00) -> faf65604-c3ad-4263-b4d5-02bd190a38e2 (8987.00/9034.00) -> 39d0a3f5-6ab5-464b-8c99-e3a3da677635 (9452.00/9528.00) -> end (10000.00/10000.00)
Antenna: DSS-26
Value: 1
Label: 2109
start (0.00/0.00) -> 4105df38-bb76-45ef-830f-cfb0ce578f24 (615.00/678.00) -> 45f01bb2-5faa-4b10-9f5a-f330e07edaab (811.00/892.00) -> e573a679-accb-4797-b9ef-4b7f6552c185 (1380.00/1437.00) -> 415ffa04-50a2-4661-ac37-e4149b547738 (2153.00/2210.00) -> d5be93cd-4409-4bf5-93f7-ef4ecb51a26b (3351.00/3403.00) -> e9c0d5c5-67e1-4e22-8f3a-08c4cbe520da (4433.00/4523.00) -> a63b4f5f-e783-45dc-9c7c-82f86cebb085 (4781.00/4882.00) -> 853e4321-63ce-429f-b5c9-bdf6da11eb58 (6035.00/6085.00) -> 0557a55e-1c1e-4659-9a19-3f7784f45236 (7115.00/7169.00) -> 2a3e0403-31a3-4d0d-a4e2-80f9488eab86 (9387.00/9473.00) -> end (10000.00/10000.00)
Antenna: DSS-34
Value: 1
Label: 1643
start (0.00/0.00) -> 350f7ad1-a239-4793-b2af-1c8bfac1b8f9 (362.00/443.00) -> 9c168268-c3df-4f26-bf24-605bf39acdd0 (1289.00/1369.00) -> d79c2198-83e0-4297-a2ad-7ac4f5b09f37 (4692.00/4737.00) -> 2c10028a-fc41-457a-b95b-8b0adc5181bf (5253.00/5335.00) -> bef454db-f349-4328-99f6-b1932814614e (6402.00/6474.00) -> d4a54bfd-096b-44ca-a12c-feff75964c11 (7283.00/7379.00) -> 07c9f09d-b15e-4a7b-8b08-f2873148b374 (7501.00/7593.00) -> 4e33051f-710b-44a5-9990-c8173dd777e1 (8036.00/8089.00) -> bd07ee8c-04df-4e03-9abb-22cb4c9f4f66 (8896.00/8991.00) -> 53c1202d-a265-4bec-8cc4-ddcea16f1e44 (9066.00/9158.00) -> end (10000.00/10000.00)
Antenna: DSS-36
Value: 1
Label: 4923
start (0.00/0.00) -> 92acb501-b7c7-492c-874a-e9bd5e590087 (271.00/341.00) -> 51b7762f-bb9b-46c1-b8c3-2e49f095d5ab (565.00/621.00) -> 00daccb8-3790-4888-ac4e-24db73376809 (1583.00/1650.00) -> 343b8f12-0ebb-49b3-a94d-c89537739c2c (2324.00/2402.00) -> f6ff82bc-5d09-426d-8468-4fa61a7bbc1d (2602.00/2681.00) -> 0dfe2d4e-79e4-4589-bf56-25b2bcfafd46 (6803.00/6858.00) -> 0dfe2d4e-79e4-4589-bf56-25b2bcfafd46 (6933.00/6988.00) -> 846b2c2f-b5ed-4e70-81a3-4906d8f94021 (7063.00/7143.00) -> 395f5b4b-95c3-44e9-b577-97cdcc67abc2 (7267.00/7358.00) -> f396539c-cde1-41e3-93aa-a53fff7feeaf (7787.00/7856.00) -> e45c3516-59c9-4ecf-838f-3ff3e7df3602 (8940.00/8985.00) -> end (10000.00/10000.00)
Antenna: DSS-54
Value: 1
Label: 5017
start (0.00/0.00) -> 9e8bbfc0-e421-4851-be07-8c291b905d7e (1153.00/1212.00) -> 05c5b140-5dd1-4e61-a83f-e41ff9e60df6 (2290.00/2372.00) -> df37a711-c78b-4517-80a6-418ea1039527 (2922.00/3001.00) -> 4560ae7d-dc55-4380-b90c-602b342adc07 (4169.00/4243.00) -> 5ba730b5-fa03-4a11-a63a-cb2ecfe3f39b (5130.00/5231.00) -> 5bfbd7b3-0b16-43b9-aafb-578be1fcb9a8 (8553.00/8627.00) -> 0296ceb8-68cd-4a82-ba80-0922c0b0af86 (9312.00/9374.00) -> end (10000.00/10000.00)
'''

# %%
def parse_data(data):
    antenna_data = defaultdict(list)
    current_antenna = None

    for line in data.split('\n'):
        antenna_match = re.match(r'Antenna: (\S+)', line)
        if antenna_match:
            current_antenna = antenna_match.group(1)
            continue

        if current_antenna:
            job_match = re.findall(r'(\S+)\s\((\d+\.\d+)/(\d+\.\d+)\)', line)
            if job_match:
                for job in job_match:
                    job_id, start, end = job
                    antenna_data[current_antenna].append({
                        'job_id': job_id,
                        'start': float(start),
                        'end': float(end)
                    })

    return antenna_data

# %%
import re
from collections import defaultdict
antenaa_data = parse_data(data)

# %%
# iterate throught dsn_data and check if each scheduled job is within the time window of the antenna
# iterate over all antennas
for antenna, jobs in antenaa_data.items():
    for job in jobs:
        # if job == start or end skip
        if job['start'] == 0 or job['end'] == 28500:
            continue
        for track in dsn_data['W10_2018']:
            #print(track)
            if track['track_id'] == job['job_id']:

                #print(track['track_id'], job['start'], job['end'])
                # check if job is within the time window of the antenna
                # check the viewpoints in track['resource_vp_dict']['DSS-24']
                for vp in track['resource_vp_dict'][antenna]:
                    #print(vp)
                    if vp['RISE'] <= job['start'] <= vp['SET']:
                        #print('job is within the time window of the antenna')
                        break
                else:
                    print('--------------------------------')
                    print('job is not within the time window of the antenna')
                    print(track['track_id'], job['start'], job['end'])
                    print(vp)
                    print('--------------------------------')
